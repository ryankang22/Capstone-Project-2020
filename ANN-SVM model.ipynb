# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path='/content/drive/My Drive/diagnosis.csv'

diagnosis=pd.read_csv(path)

# %%
diagnosis['diagnosis'] = diagnosis['diagnosis'].map({'M':1,'B':0})

y= diagnosis.diagnosis
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
drop_list=['Unnamed: 32','id','diagnosis']
x=diagnosis.drop(drop_list, axis=1)
x.dtypes
x.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
x = (x - x.mean()) / (x.std()) 
x.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0     1.096100     -2.071512  ...        2.748204                 1.935312
# 1     1.828212     -0.353322  ...       -0.243675                 0.280943
# 2     1.578499      0.455786  ...        1.151242                 0.201214
# 3    -0.768233      0.253509  ...        6.040726                 4.930672
# 4     1.748758     -1.150804  ...       -0.867590                -0.396751
#
# [5 rows x 30 columns]

# %%
diagnosis = pd.concat([y,x], axis = 1)
diagnosis.head()
# Out:
#    diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          1     1.096100  ...        2.748204                 1.935312
# 1          1     1.828212  ...       -0.243675                 0.280943
# 2          1     1.578499  ...        1.151242                 0.201214
# 3          1    -0.768233  ...        6.040726                 4.930672
# 4          1     1.748758  ...       -0.867590                -0.396751
#
# [5 rows x 31 columns]

# %% [markdown]
# # ANN+SVM

# %%
from sklearn.utils import resample

# concatenate our training data back together
data_concat = pd.concat([pd.DataFrame(X_train), pd.DataFrame(y_train)], axis=1)

# separate minority and majority classes
y_B_0= data_concat[data_concat.iloc[:, -1] == 0]
y_M_1= data_concat[data_concat.iloc[:, -1] == 1]

# upsample minority
y_M_1_upsampled = resample(y_M_1,
                          replace=True, # sample with replacement
                          n_samples=len(y_B_0), # match number in majority class
                          random_state=345) # reproducible results

# combine majority and upsampled minority
upsampled = pd.concat([pd.DataFrame(y_B_0), pd.DataFrame(y_M_1_upsampled )])

# check new class counts
upsampled.iloc[:, -1].value_counts()

y_train = upsampled.iloc[:, -1].values
X_train = upsampled.iloc[:, :-1].values

# %%
from sklearn.model_selection import train_test_split 
#Split 70% train 30% test 
X_train,X_test,y_train,y_test = train_test_split(x.values, y.values, test_size=0.3, random_state = 50)

X_train.shape
# Out:
# (398, 30)

# %%
from keras.models import Sequential
from keras.layers import Dense , Dropout, GRU
from keras.regularizers import l2
classifier = Sequential() # Initialising the ANN

classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
classifier.add(Dropout(0.1))
classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dropout(0.1))
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dropout(0.1))
#output layer 
classifier.add(Dense(units = 1, kernel_regularizer = l2(1e-4), activation = 'linear'))

classifier.compile(optimizer = 'rmsprop', loss = 'hinge', metrics = ['accuracy'])

## Fitting the data
model_history = classifier.fit(X_train, y_train, batch_size = 1, epochs = 120, validation_split=0.2)
# Out:
# Using TensorFlow backend.
# Train on 318 samples, validate on 80 samples
# Epoch 1/120
# 318/318 [==============================] - 1s 3ms/step - loss: 0.7969 - accuracy: 0.7233 - val_loss: 0.6096 - val_accuracy: 0.7375
# Epoch 2/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.6981 - val_loss: 0.4760 - val_accuracy: 0.6250
# Epoch 3/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.4163 - accuracy: 0.5943 - val_loss: 0.3586 - val_accuracy: 0.0750
# Epoch 4/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.2773 - accuracy: 0.0692 - val_loss: 0.2322 - val_accuracy: 0.0500
# Epoch 5/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.1474 - accuracy: 0.0597 - val_loss: 0.1128 - val_accuracy: 0.0250
# Epoch 6/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0604 - accuracy: 0.0346 - val_loss: 0.0854 - val_accuracy: 0.0250
# Epoch 7/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0548 - accuracy: 0.0377 - val_loss: 0.0800 - val_accuracy: 0.0375
# Epoch 8/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0505 - accuracy: 0.0252 - val_loss: 0.0884 - val_accuracy: 0.0250
# Epoch 9/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0587 - accuracy: 0.0252 - val_loss: 0.0732 - val_accuracy: 0.0500
# Epoch 10/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0488 - accuracy: 0.0126 - val_loss: 0.0790 - val_accuracy: 0.0375
# Epoch 11/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0418 - accuracy: 0.0189 - val_loss: 0.0697 - val_accuracy: 0.0500
# Epoch 12/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0503 - accuracy: 0.0220 - val_loss: 0.0590 - val_accuracy: 0.0500
# Epoch 13/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0562 - accuracy: 0.0157 - val_loss: 0.0593 - val_accuracy: 0.0500
# Epoch 14/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0518 - accuracy: 0.0189 - val_loss: 0.0558 - val_accuracy: 0.0500
# Epoch 15/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0516 - accuracy: 0.0157 - val_loss: 0.0522 - val_accuracy: 0.0500
# Epoch 16/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.0031 - val_loss: 0.0500 - val_accuracy: 0.0375
# Epoch 17/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0363 - accuracy: 0.0189 - val_loss: 0.0509 - val_accuracy: 0.0500
# Epoch 18/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0404 - accuracy: 0.0220 - val_loss: 0.0494 - val_accuracy: 0.0625
# Epoch 19/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.0126 - val_loss: 0.0484 - val_accuracy: 0.0625
# Epoch 20/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0358 - accuracy: 0.0220 - val_loss: 0.0487 - val_accuracy: 0.0375
# Epoch 21/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0400 - accuracy: 0.0252 - val_loss: 0.0447 - val_accuracy: 0.0375
# Epoch 22/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0358 - accuracy: 0.0157 - val_loss: 0.0442 - val_accuracy: 0.0375
# Epoch 23/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0371 - accuracy: 0.0283 - val_loss: 0.0455 - val_accuracy: 0.0500
# Epoch 24/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0342 - accuracy: 0.0126 - val_loss: 0.0501 - val_accuracy: 0.0375
# Epoch 25/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0580 - accuracy: 0.0063 - val_loss: 0.0574 - val_accuracy: 0.0250
# Epoch 26/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0405 - accuracy: 0.0220 - val_loss: 0.0514 - val_accuracy: 0.0375
# Epoch 27/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0295 - accuracy: 0.0189 - val_loss: 0.0524 - val_accuracy: 0.0375
# Epoch 28/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0294 - accuracy: 0.0126 - val_loss: 0.0456 - val_accuracy: 0.0375
# Epoch 29/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0301 - accuracy: 0.0189 - val_loss: 0.0450 - val_accuracy: 0.0375
# Epoch 30/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0300 - accuracy: 0.0126 - val_loss: 0.0502 - val_accuracy: 0.0250
# Epoch 31/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0248 - accuracy: 0.0157 - val_loss: 0.0499 - val_accuracy: 0.0375
# Epoch 32/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0303 - accuracy: 0.0157 - val_loss: 0.0529 - val_accuracy: 0.0375
# Epoch 33/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0249 - accuracy: 0.0252 - val_loss: 0.0522 - val_accuracy: 0.0250
# Epoch 34/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0203 - accuracy: 0.0346 - val_loss: 0.0543 - val_accuracy: 0.0375
# Epoch 35/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0350 - accuracy: 0.0346 - val_loss: 0.0476 - val_accuracy: 0.0500
# Epoch 36/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0238 - accuracy: 0.0346 - val_loss: 0.0467 - val_accuracy: 0.0375
# Epoch 37/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0297 - accuracy: 0.0157 - val_loss: 0.0548 - val_accuracy: 0.0375
# Epoch 38/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.0220 - val_loss: 0.0548 - val_accuracy: 0.0375
# Epoch 39/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.0157 - val_loss: 0.0486 - val_accuracy: 0.0375
# Epoch 40/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.0189 - val_loss: 0.0525 - val_accuracy: 0.0125
# Epoch 41/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0313 - accuracy: 0.0283 - val_loss: 0.0574 - val_accuracy: 0.0375
# Epoch 42/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0263 - accuracy: 0.0220 - val_loss: 0.0554 - val_accuracy: 0.0250
# Epoch 43/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0235 - accuracy: 0.0220 - val_loss: 0.0615 - val_accuracy: 0.0500
# Epoch 44/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0277 - accuracy: 0.0157 - val_loss: 0.0582 - val_accuracy: 0.0250
# Epoch 45/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0279 - accuracy: 0.0252 - val_loss: 0.0527 - val_accuracy: 0.0125
# Epoch 46/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0337 - accuracy: 0.0220 - val_loss: 0.0448 - val_accuracy: 0.0125
# Epoch 47/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0239 - accuracy: 0.0157 - val_loss: 0.0475 - val_accuracy: 0.0125
# Epoch 48/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0201 - accuracy: 0.0189 - val_loss: 0.0512 - val_accuracy: 0.0250
# Epoch 49/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0225 - accuracy: 0.0252 - val_loss: 0.0509 - val_accuracy: 0.0250
# Epoch 50/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0174 - accuracy: 0.0252 - val_loss: 0.0533 - val_accuracy: 0.0250
# Epoch 51/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0229 - accuracy: 0.0314 - val_loss: 0.0522 - val_accuracy: 0.0375
# Epoch 52/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0196 - accuracy: 0.0157 - val_loss: 0.0458 - val_accuracy: 0.0250
# Epoch 53/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0234 - accuracy: 0.0189 - val_loss: 0.0449 - val_accuracy: 0.0250
# Epoch 54/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0381 - accuracy: 0.0252 - val_loss: 0.0563 - val_accuracy: 0.0375
# Epoch 55/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0254 - accuracy: 0.0252 - val_loss: 0.0498 - val_accuracy: 0.0375
# Epoch 56/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0260 - accuracy: 0.0220 - val_loss: 0.0513 - val_accuracy: 0.0250
# Epoch 57/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0235 - accuracy: 0.0252 - val_loss: 0.0513 - val_accuracy: 0.0250
# Epoch 58/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0285 - accuracy: 0.0314 - val_loss: 0.0499 - val_accuracy: 0.0250
# Epoch 59/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0303 - accuracy: 0.0220 - val_loss: 0.0467 - val_accuracy: 0.0375
# Epoch 60/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0176 - accuracy: 0.0220 - val_loss: 0.0483 - val_accuracy: 0.0250
# Epoch 61/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0283 - accuracy: 0.0283 - val_loss: 0.0466 - val_accuracy: 0.0375
# Epoch 62/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0332 - accuracy: 0.0346 - val_loss: 0.0487 - val_accuracy: 0.0250
# Epoch 63/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0185 - accuracy: 0.0409 - val_loss: 0.0513 - val_accuracy: 0.0375
# Epoch 64/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0182 - accuracy: 0.0346 - val_loss: 0.0439 - val_accuracy: 0.0250
# Epoch 65/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0237 - accuracy: 0.0157 - val_loss: 0.0430 - val_accuracy: 0.0375
# Epoch 66/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0180 - accuracy: 0.0220 - val_loss: 0.0423 - val_accuracy: 0.0250
# Epoch 67/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0139 - accuracy: 0.0252 - val_loss: 0.0412 - val_accuracy: 0.0250
# Epoch 68/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0300 - accuracy: 0.0157 - val_loss: 0.0402 - val_accuracy: 0.0250
# Epoch 69/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0235 - accuracy: 0.0283 - val_loss: 0.0404 - val_accuracy: 0.0250
# Epoch 70/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0212 - accuracy: 0.0252 - val_loss: 0.0379 - val_accuracy: 0.0250
# Epoch 71/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0149 - accuracy: 0.0440 - val_loss: 0.0349 - val_accuracy: 0.0250
# Epoch 72/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0141 - accuracy: 0.0252 - val_loss: 0.0376 - val_accuracy: 0.0500
# Epoch 73/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.0189 - val_loss: 0.0427 - val_accuracy: 0.0250
# Epoch 74/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.0220 - val_loss: 0.0362 - val_accuracy: 0.0250
# Epoch 75/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0347 - accuracy: 0.0157 - val_loss: 0.0397 - val_accuracy: 0.0250
# Epoch 76/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0160 - accuracy: 0.0314 - val_loss: 0.0424 - val_accuracy: 0.0375
# Epoch 77/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0186 - accuracy: 0.0220 - val_loss: 0.0345 - val_accuracy: 0.0250
# Epoch 78/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0279 - accuracy: 0.0283 - val_loss: 0.0409 - val_accuracy: 0.0250
# Epoch 79/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0159 - accuracy: 0.0189 - val_loss: 0.0415 - val_accuracy: 0.0250
# Epoch 80/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0186 - accuracy: 0.0346 - val_loss: 0.0422 - val_accuracy: 0.0375
# Epoch 81/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0270 - accuracy: 0.0189 - val_loss: 0.0402 - val_accuracy: 0.0250
# Epoch 82/120
# 318/318 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.0346 - val_loss: 0.0424 - val_accuracy: 0.0375
# Epoch 83/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0150 - accuracy: 0.0283 - val_loss: 0.0373 - val_accuracy: 0.0375
# Epoch 84/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0244 - accuracy: 0.0252 - val_loss: 0.0387 - val_accuracy: 0.0250
# Epoch 85/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0189 - accuracy: 0.0126 - val_loss: 0.0426 - val_accuracy: 0.0375
# Epoch 86/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0239 - accuracy: 0.0157 - val_loss: 0.0361 - val_accuracy: 0.0250
# Epoch 87/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0213 - accuracy: 0.0220 - val_loss: 0.0432 - val_accuracy: 0.0375
# Epoch 88/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0153 - accuracy: 0.0314 - val_loss: 0.0345 - val_accuracy: 0.0250
# Epoch 89/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0157 - accuracy: 0.0157 - val_loss: 0.0436 - val_accuracy: 0.0250
# Epoch 90/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0184 - accuracy: 0.0346 - val_loss: 0.0398 - val_accuracy: 0.0375
# Epoch 91/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0234 - accuracy: 0.0220 - val_loss: 0.0444 - val_accuracy: 0.0500
# Epoch 92/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0189 - accuracy: 0.0189 - val_loss: 0.0369 - val_accuracy: 0.0375
# Epoch 93/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0216 - accuracy: 0.0283 - val_loss: 0.0388 - val_accuracy: 0.0375
# Epoch 94/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0179 - accuracy: 0.0126 - val_loss: 0.0407 - val_accuracy: 0.0375
# Epoch 95/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0224 - accuracy: 0.0283 - val_loss: 0.0407 - val_accuracy: 0.0250
# Epoch 96/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0292 - accuracy: 0.0220 - val_loss: 0.0340 - val_accuracy: 0.0250
# Epoch 97/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0302 - accuracy: 0.0220 - val_loss: 0.0430 - val_accuracy: 0.0125
# Epoch 98/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0194 - accuracy: 0.0252 - val_loss: 0.0465 - val_accuracy: 0.0250
# Epoch 99/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0229 - accuracy: 0.0377 - val_loss: 0.0388 - val_accuracy: 0.0125
# Epoch 100/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0150 - accuracy: 0.0346 - val_loss: 0.0408 - val_accuracy: 0.0250
# Epoch 101/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0202 - accuracy: 0.0157 - val_loss: 0.0381 - val_accuracy: 0.0375
# Epoch 102/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0211 - accuracy: 0.0126 - val_loss: 0.0452 - val_accuracy: 0.0375
# Epoch 103/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0224 - accuracy: 0.0252 - val_loss: 0.0419 - val_accuracy: 0.0375
# Epoch 104/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0146 - accuracy: 0.0157 - val_loss: 0.0410 - val_accuracy: 0.0250
# Epoch 105/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0185 - accuracy: 0.0189 - val_loss: 0.0446 - val_accuracy: 0.0250
# Epoch 106/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0161 - accuracy: 0.0189 - val_loss: 0.0435 - val_accuracy: 0.0250
# Epoch 107/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0189 - accuracy: 0.0220 - val_loss: 0.0444 - val_accuracy: 0.0125
# Epoch 108/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0147 - accuracy: 0.0094 - val_loss: 0.0385 - val_accuracy: 0.0250
# Epoch 109/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0140 - accuracy: 0.0189 - val_loss: 0.0388 - val_accuracy: 0.0250
# Epoch 110/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0134 - accuracy: 0.0126 - val_loss: 0.0399 - val_accuracy: 0.0250
# Epoch 111/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0115 - accuracy: 0.0126 - val_loss: 0.0404 - val_accuracy: 0.0375
# Epoch 112/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0254 - accuracy: 0.0314 - val_loss: 0.0443 - val_accuracy: 0.0375
# Epoch 113/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0261 - accuracy: 0.0252 - val_loss: 0.0447 - val_accuracy: 0.0375
# Epoch 114/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0191 - accuracy: 0.0314 - val_loss: 0.0455 - val_accuracy: 0.0375
# Epoch 115/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0186 - accuracy: 0.0220 - val_loss: 0.0476 - val_accuracy: 0.0250
# Epoch 116/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0261 - accuracy: 0.0189 - val_loss: 0.0485 - val_accuracy: 0.0250
# Epoch 117/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0191 - accuracy: 0.0252 - val_loss: 0.0454 - val_accuracy: 0.0250
# Epoch 118/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0104 - accuracy: 0.0314 - val_loss: 0.0471 - val_accuracy: 0.0375
# Epoch 119/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0247 - accuracy: 0.0189 - val_loss: 0.0488 - val_accuracy: 0.0375
# Epoch 120/120
# 318/318 [==============================] - 1s 2ms/step - loss: 0.0118 - accuracy: 0.0346 - val_loss: 0.0474 - val_accuracy: 0.0375

# %%
from tensorflow import keras
keras.utils.plot_model(classifier, "ANN model.png", show_shapes = True )

# %%
classifier.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 16)                496
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 693
# Trainable params: 693
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn import metrics
fin_predict = classifier.predict(X_test)
fin_predict = (fin_predict >= 0.5)
print(metrics.accuracy_score(y_true = y_test, y_pred=fin_predict))
# Out:
# 0.9649122807017544

# %%
# plot training & validation accuracy values

plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()


# plot training & validation loss values

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Accuracy')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()
